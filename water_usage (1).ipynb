# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read.csv("water_usage_prediction.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-11403bae9247> in <cell line: 0>()
# ----> 1 df = pd.read.csv("water_usage_prediction.csv")
#       2 df.head()
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
df = pd.read.csv("water_usage_prediction.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-8f659e4f49b0> in <cell line: 0>()
# ----> 1 df = pd.read.csv("water_usage_prediction.csv")
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
df = pd.read_csv("water_usage_prediction.csv")

# %%
df.head()
# Out:
#               State  Year  Population (millions)  Annual Rainfall (mm)  \
# 0  Himachal Pradesh  2014                  62.06                2335.9
# 1       Maharashtra  2023                 161.10                2896.7
# 2        Tamil Nadu  2003                 249.33                 653.0
# 3           Haryana  2016                  37.34                 972.3
# 4      Chhattisgarh  2006                 152.04                 825.5
#
#    Agricultural Land (sq km)  Industrial Water Usage (billion liters)  \
# 0                    27858.7                                   217.78
# 1                     4921.7                                   283.42
# 2                    29305.3                                   257.51
# 3                    71026.8                                   204.25
# 4                   174406.8                                   281.18
#
#    Domestic Water Usage (billion liters)  \
# 0                                 173.96
# 1                                 169.84
# 2                                 257.38
# 3                                 218.42
# 4                                  27.66
#
#    Total Water Consumption (billion liters)
# 0                                    391.74
# 1                                    453.26
# 2                                    514.89
# 3                                    422.67
# 4                                    308.84

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   State                                     5000 non-null   object
#  1   Year                                      5000 non-null   int64
#  2   Population (millions)                     5000 non-null   float64
#  3   Annual Rainfall (mm)                      5000 non-null   float64
#  4   Agricultural Land (sq km)                 5000 non-null   float64
#  5   Industrial Water Usage (billion liters)   5000 non-null   float64
#  6   Domestic Water Usage (billion liters)     5000 non-null   float64
#  7   Total Water Consumption (billion liters)  5000 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 312.6+ KB

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-123bb4f5928d> in <cell line: 0>()
# ----> 1 df.descr()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'descr'

# %%
df.drop(columns="Year",inplace=True)

# %%
df.head()
# Out:
#               State  Population (millions)  Annual Rainfall (mm)  \
# 0  Himachal Pradesh                  62.06                2335.9
# 1       Maharashtra                 161.10                2896.7
# 2        Tamil Nadu                 249.33                 653.0
# 3           Haryana                  37.34                 972.3
# 4      Chhattisgarh                 152.04                 825.5
#
#    Agricultural Land (sq km)  Industrial Water Usage (billion liters)  \
# 0                    27858.7                                   217.78
# 1                     4921.7                                   283.42
# 2                    29305.3                                   257.51
# 3                    71026.8                                   204.25
# 4                   174406.8                                   281.18
#
#    Domestic Water Usage (billion liters)  \
# 0                                 173.96
# 1                                 169.84
# 2                                 257.38
# 3                                 218.42
# 4                                  27.66
#
#    Total Water Consumption (billion liters)
# 0                                    391.74
# 1                                    453.26
# 2                                    514.89
# 3                                    422.67
# 4                                    308.84

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['State'] = label_encoder.fit_transform(df['State'])

# %%
print("Model function")
